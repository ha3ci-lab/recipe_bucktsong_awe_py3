# %%
import numpy as np

# %%
dp1_feat = "/home/ldap-users/s2210403/recipe_bucktsong_awe_py3/features/mfcc/buckeye/devpart1.dd.npz"
sd1_feat = "/home/ldap-users/s2210403/recipe_bucktsong_awe_py3/features/mfcc/buckeye/devpart1.samediff.dd.npz"

# %%
# Load the .npz file
npz_file = np.load(sd1_feat)  # Replace 'your_file.npz' with your file's name

# List all arrays contained in the .npz file
print("Arrays in the .npz file:", npz_file.files)

# Access a specific array (replace 'array_key' with the actual key)
# For example, if you want to access the first array listed in npz_file.files
if npz_file.files:
    first_key = npz_file.files[0]
    first_array = npz_file[first_key]
    # print(first_array)
    print(f"First array's shape: {first_array.shape}")

# Close the file
npz_file.close()
# Out:
# Arrays in the .npz file: ['abandoned_s06_02a_044207-044258', 'abercrombie_s06_01a_020359-020437', 'abhorrent_s03_02b_025379-025463', 'abhorrent_s03_02b_029478-029548', 'abilities_s13_01a_023881-023945', 'abortions_s05_03b_056660-056715', 'about_s16_01a_018059-018113', 'absentee_s02_01a_022991-023045', 'absentee_s03_01a_025752-025821', 'absolutely_s03_05a_038289-038381', 'absolutely_s12_01b_024432-024488', 'absolutely_s38_02b_020073-020156', 'absorbs_s11_03b_001042-001096', 'abstinence_s08_02b_050442-050500', 'abstract_s16_01a_055696-055759', 'abstract_s16_01a_055946-056009', 'abuse_s02_05b_002754-002811', 'abused_s02_05b_024962-025014', 'academy_s10_01b_048142-048202', 'accents_s10_01b_016372-016429', 'acceptable_s12_03a_030143-030201', 'acceptable_s12_03a_037832-037892', 'accepting_s02_02b_038180-038231', 'accepting_s06_01b_040138-040205', 'access_s08_03a_000904-000978', 'access_s08_03a_058745-058811', 'accessible_s05_02b_053136-053189', 'accessible_s05_03b_011417-011477', 'accident
# ...
